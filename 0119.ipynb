# %% [markdown]
# ### Pandas 데이터 입출력(CSV 입출력)

# %%
import numpy as np
import pandas as pd
da = np.array([[1,1.11,'one'],[2,'','two'],['누락',3.33,'three']])
cf = pd.DataFrame(da,columns=['c1','c2','c3'])
cf
# Out:
#    c1    c2     c3
# 0   1  1.11    one
# 1   2          two
# 2  누락  3.33  three

# %% [markdown]
# ### pandas 데이터 csv로 출력하기 pandas.DataFrame.to.csv(index=True/기본값)

# %%
cf_write = cf.to_csv('C:/Python/0119.csv',index=False,encoding='UTF-8') # * 오른쪽 다 키워드인자

# %%
cf_read = pd.read_csv('C:/Python/0119.csv')
cf_read
# Out:
#    c1    c2     c3
# 0   1  1.11    one
# 1   2   NaN    two
# 2  누락  3.33  three

# %%
cf.to_csv('C:/Python/0119_2.csv',index=False,header=False)

# %%
pd.read_csv('C:/Python/0119_2.csv',names = ['c1','c2','c3'])
# Out:
#    c1    c2     c3
# 0   1  1.11    one
# 1   2   NaN    two
# 2  누락  3.33  three

# %%
# %%writefile sample3.txt
# c1        c2        c3        c4
# 0.179181 -1.538472  1.347553  0.43381
# 1.024209  0.087307 -1.281997  0.49265
# 0.417899 -2.002308  0.255245 -1.10515
# Out:
# Writing sample3.txt

# %%
pd.read_csv('C:/Python/sample3.txt',sep='\s+') # 구분자 지정 \s+: 길이가 정해지지 않은 공백 구분자 \s: 띄어쓰기, +연속된
# Out:
#          c1        c2        c3       c4
# 0  0.179181 -1.538472  1.347553  0.43381
# 1  1.024209  0.087307 -1.281997  0.49265
# 2  0.417899 -2.002308  0.255245 -1.10515

# %%
# %%writefile sample4.txt
# 파일 제목: sample4.txt
# 데이터 포맷의 설명:
# c1, c2, c3
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Overwriting sample4.txt

# %%
# 위쪽의 부가적인 설명을 제거하고 가져오려고 함.
pd.read_csv('C:/Python/sample4.txt',skiprows=[0,1])  # skiprows: 0번째와 1번째 줄을 생략하기, range써서도 가능
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   three

# %%
# 자료 안 특정한 값을 NaN으로 취급하고 싶으면 na_values 인수에 NaN 값으로 취급할 값을 넣습니다.
df_na_val = pd.read_csv('C:/Python/0119.csv', na_values=['누락'])
df_na_val
# Out:
#     c1    c2     c3
# 0  1.0  1.11    one
# 1  2.0   NaN    two
# 2  NaN  3.33  three

# %%
df_na_val.to_csv('C:/Python/sample5.txt', sep='|' )

# %%
# na_rep 키워드 인수를 사용하면 NaN 표시값을 바꿀 수도 있습니다.
df_na_val.to_csv('C:/Python/sample6.csv', na_rep ='누락' )

# %%
# 온라인의 csv 파일 가져오기
pd.set_option('display.max_rows', None) # 모든 행 출력
pd.set_option('display.max_columns', None) # 모든 열 출력
titanic = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
titanic
# Out:
#      survived     sex    age  n_siblings_spouses  parch      fare   class  \
# 0           0    male  22.00                   1      0    7.2500   Third
# 1           1  female  38.00                   1      0   71.2833   First
# 2           1  female  26.00                   0      0    7.9250   Third
# 3           1  female  35.00                   1      0   53.1000   First
# 4           0    male  28.00                   0      0    8.4583   Third
# 5           0    male   2.00                   3      1   21.0750   Third
# 6           1  female  27.00                   0      2   11.1333   Third
# 7           1  female  14.00                   1      0   30.0708  Second
# 8           1  female   4.00                   1      1   16.7000   Third
# 9           0    male  20.00                   0      0    8.0500   Third
# 10          0    male  39.00                   1      5   31.2750   Third
# 11          0  female  14.00                   0      0    7.8542   Third
# ...

# %%
titanic.head(20)
# Out:
#     survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0          0    male  22.0                   1      0   7.2500   Third
# 1          1  female  38.0                   1      0  71.2833   First
# 2          1  female  26.0                   0      0   7.9250   Third
# 3          1  female  35.0                   1      0  53.1000   First
# 4          0    male  28.0                   0      0   8.4583   Third
# 5          0    male   2.0                   3      1  21.0750   Third
# 6          1  female  27.0                   0      2  11.1333   Third
# 7          1  female  14.0                   1      0  30.0708  Second
# 8          1  female   4.0                   1      1  16.7000   Third
# 9          0    male  20.0                   0      0   8.0500   Third
# 10         0    male  39.0                   1      5  31.2750   Third
# 11         0  female  14.0                   0      0   7.8542   Third
# ...

# %%
# DataFrame 고급 인덱싱: loc- index 값 기반의 2차원 인덱싱, iloc- 순서를 나타내는 정수 기반의 2차원 인덱싱
# df.loc[row 인덱싱 값], df.loc[row 인덱싱 값, column 인덱싱 값] 생략하면  column은 전체로 판단
# row 인덱싱 값은 정수 또는 row index 데이터이며 column 인덱싱은 문자열 or 숫자 or RangeIndex

# %%
num = np.arange(10,22).reshape(3,4)
df = pd.DataFrame(num,index=[_ for _ in 'abc'],columns=[_ for _ in 'ABCD'])
df
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %%
df.loc['a']
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: a, dtype: int32

# %%
df.loc['b':'c'] # db['b':'c'] 와 같습니다.
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %%
df.loc[['b','c']] # 데이터의 리스트 자료형도 가능합니다.
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %%
df.A > 15 # column은 .columns로도 접근 가능
# Out:
# a    False
# b    False
# c     True
# Name: A, dtype: bool

# %%
df.loc[ df.A > 15] # .loc[]안에 True 값만을 가져오는 애들로 결과를 도출해낼 수 도 있다. 즉, Boolean Series로도 인덱싱 할 수 있습니다.
# Out:
#     A   B   C   D
# c  18  19  20  21

# %%
def select_rows(df,num): # boolean으로 return반환합니다.
    return df.A > num    # 함수를 만들어서 인덱싱하는데 사용할 수도 있습니다.
df.loc[select_rows(df,10)]
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %%
df2 = pd.DataFrame(np.arange(10,26).reshape(4,4), columns=['A','B','C','D'])
df2 # index가 default 값으로 생성된 경우 슬라이싱 마지막 숫자가 포함된 결과를 가져옵니다.
# Out:
#     A   B   C   D
# 0  10  11  12  13
# 1  14  15  16  17
# 2  18  19  20  21
# 3  22  23  24  25

# %%
df2.loc[0:3]
# Out:
#     A   B   C   D
# 0  10  11  12  13
# 1  14  15  16  17
# 2  18  19  20  21
# 3  22  23  24  25

# %%
df2.loc[0:3,'A']
# Out:
# 0    10
# 1    14
# 2    18
# 3    22
# Name: A, dtype: int32

# %%
df2.loc[0,:]
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: 0, dtype: int32

# %%
# iloc는 정수 인덱스만 받습니다. 나머지는 loc와 같습니다.
df2.iloc[2:3, 1:3]
# Out:
#     B   C
# 2  19  20

# %%
df2.iloc[-1] = df2.iloc[-1]*2
df2
# Out:
#     A   B   C   D
# 0  10  11  12  13
# 1  14  15  16  17
# 2  18  19  20  21
# 3  44  46  48  50

# %% [markdown]
# ### Series 데이터 개수 세기, .count()를 사용합니다. 이 때, NaN 값은 세지 않습니다. 그러므로 NaN 값을 찾을 때 유용합니다.

# %%
np.random.seed(2)
df = pd.DataFrame(np.random.randint(5, size=(4,4)), dtype = float)
df.iloc[2,3]=np.nan
df
# Out:
#      0    1    2    3
# 0  0.0  0.0  3.0  2.0
# 1  3.0  0.0  2.0  1.0
# 2  3.0  2.0  4.0  NaN
# 3  4.0  3.0  4.0  2.0

# %%
df.count()
# Out:
# 0    4
# 1    4
# 2    4
# 3    3
# dtype: int64

# %%
import seaborn as sns # seaborn이라는 패키지에는 데이터를 제공하고 있습니다. .load_dataset()
titanic = sns.load_dataset('titanic')
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %% [markdown]
# ### Series 카테고리 값 세기: Series의 값이 정수, 문자열, 카테고리 값인 경우에는 value_counts()메소드로 각각의 값이 나온 횟수를 셀 수 있습니다.
# ### DataFrame 카테고리에도 값을 셀 수 있습니다. 첫 인자로 label 값을 문자로 전달해야 합니다.

# %%
np.random.seed(1)
s2 = pd.Series(np.random.randint(6, size=100))
s2.tail()
# Out:
# 95    4
# 96    5
# 97    2
# 98    4
# 99    3
# dtype: int32

# %%
s2.value_counts()
# Out:
# 1    22
# 0    18
# 4    17
# 5    16
# 3    14
# 2    13
# dtype: int64

# %%
np.random.seed(2)
df = pd.DataFrame(np.random.randint(5, size= (4,4)), dtype=float )
df.iloc[2,3] = np.nan
df
# Out:
#      0    1    2    3
# 0  0.0  0.0  3.0  2.0
# 1  3.0  0.0  2.0  1.0
# 2  3.0  2.0  4.0  NaN
# 3  4.0  3.0  4.0  2.0

# %% [markdown]
# ### Series 정렬 - index 기준 sort_index(), value 기준 sort_values 하지만 value 기준으로 값을 정렬할 때 NaN값이 있는 경우 마지막으로 위치하게 됩니다.

# %%
s2.value_counts().sort_index() # 내림차순정렬을 하고 싶은 경우 ascendig = False를 넣어준다.
# Out:
# 0    18
# 1    22
# 2    13
# 3    14
# 4    17
# 5    16
# dtype: int64

# %% [markdown]
# ### DataFrame 정렬: by키워드 인수를 활용하여 정렬 기준이 되는 column을 지정해 주어야 합니다. df.sort_values(by=1)

# %%
df.sort_values(by=1)
# Out:
#      0    1    2    3
# 0  0.0  0.0  3.0  2.0
# 1  3.0  0.0  2.0  1.0
# 2  3.0  2.0  4.0  NaN
# 3  4.0  3.0  4.0  2.0

# %%
df.sort_values(by=[1,2]) # 리스트의 앞쪽부터 columns 1을 정렬하고 동일한 값이 있는 경우 그 다음 기준으로 순서를 정렬합니다.
# Out:
#      0    1    2    3
# 1  3.0  0.0  2.0  1.0
# 0  0.0  0.0  3.0  2.0
# 2  3.0  2.0  4.0  NaN
# 3  4.0  3.0  4.0  2.0

# %%
titanic['sex'].value_counts().sort_values(ascending=False)
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
titanic['age'].value_counts().sort_values(ascending=False)
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
# 30.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 26.00    18
# 27.00    18
# 35.00    18
# 32.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 34.00    15
# 33.00    15
# 23.00    15
# 39.00    14
# 42.00    13
# 17.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 44.00     9
# 48.00     9
# 47.00     9
# 9.00      8
# 54.00     8
# 1.00      7
# 51.00     7
# 14.00     6
# 52.00     6
# 37.00     6
# 49.00     6
# 41.00     6
# 3.00      6
# 15.00     5
# 43.00     5
# 58.00     5
# 56.00     4
# 5.00      4
# 11.00     4
# 60.00     4
# 8.00      4
# 62.00     4
# 65.00     3
# 7.00      3
# 61.00     3
# 46.00     3
# 6.00      3
# 71.00     2
# 45.50     2
# 28.50     2
# 32.50     2
# 55.00     2
# 40.50     2
# 59.00     2
# 0.83      2
# 0.75      2
# 57.00     2
# 30.50     2
# 63.00     2
# 13.00     2
# 64.00     2
# 10.00     2
# ...

# %%
titanic['class'].value_counts().sort_values(ascending=False)
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
titanic['alive'].value_counts().sort_values(ascending=False)
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
titanic.value_counts('age',ascending=False) # NaN값이 있는 row는 비교를 하지 않습니다.
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 30.00    25
# 28.00    25
# 19.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 35.00    18
# 27.00    18
# 26.00    18
# 31.00    17
# 16.00    17
# 23.00    15
# 34.00    15
# 20.00    15
# 33.00    15
# 39.00    14
# 40.00    13
# 42.00    13
# 17.00    13
# 45.00    12
# 38.00    11
# 2.00     10
# 4.00     10
# 50.00    10
# 48.00     9
# 47.00     9
# 44.00     9
# 9.00      8
# 54.00     8
# 1.00      7
# 51.00     7
# 41.00     6
# 37.00     6
# 49.00     6
# 14.00     6
# 3.00      6
# 52.00     6
# 43.00     5
# 58.00     5
# 15.00     5
# 8.00      4
# 5.00      4
# 56.00     4
# 60.00     4
# 62.00     4
# 11.00     4
# 7.00      3
# 65.00     3
# 46.00     3
# 61.00     3
# 6.00      3
# 64.00     2
# 0.83      2
# 55.00     2
# 57.00     2
# 0.75      2
# 10.00     2
# 45.50     2
# 32.50     2
# 71.00     2
# 13.00     2
# 40.50     2
# 70.00     2
# 59.00     2
# 30.50     2
# 63.00     2
# ...

# %%
# row와 column의 합계를 구할 때는 sum(axis)메소드를 사용합니다.
print(df)
df.sum(axis=1)
# Out:
#      0    1    2    3
# 0  0.0  0.0  3.0  2.0
# 1  3.0  0.0  2.0  1.0
# 2  3.0  2.0  4.0  NaN
# 3  4.0  3.0  4.0  2.0
# 0     5.0
# 1     6.0
# 2     9.0
# 3    13.0
# dtype: float64

# %%
df.sum(axis=0) # 디폴트 값이 0이므로 생략 가능합니다.
# Out:
# 0    10.0
# 1     5.0
# 2    13.0
# 3     5.0
# dtype: float64

# %%
# 1번
round(titanic['age'].mean(),1)
# Out:
# 29.7

# %%
# 2번
round(titanic.loc[titanic.sex== 'female']['age'].mean(),1)
# Out:
# 27.9

# %%
# 3번
p_1 = titanic.loc[titanic.pclass == 1] # 1등실
fem = p_1.loc[p_1.sex == 'female'] # 여성 승객
round(fem['age'].mean(),1) # 평균 나이 // &로 묶어서하면 한줄에 작성 가능함!
import random
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14388\3837150189.py in <module>
#       1 # 3번
# ----> 2 p_1 = titanic.loc[titanic.pclass == 1] # 1등실
#       3 fem = p_1.loc[p_1.sex == 'female'] # 여성 승객
#       4 round(fem['age'].mean(),1) # 평균 나이 // &로 묶어서하면 한줄에 작성 가능함!
#       5 import random
#
# NameError: name 'titanic' is not defined

# %%
import random
import numpy
class Team:
    """
    클래스 속성
    count (default 0)
    order (default 빈 리스트)
    인스턴스 속성
    number (필수)
    name (default None)
    비공개 인스턴스 속성
    member (default 빈 set)
    메서드
    add_member(): 이름을 인자로 받고 해당 이름이 member 요소로 있는 지 확인하고 있으면 “000 님은 이미 팀에 있습니다.”를 출력하고 없으면 member에 추가하고 “000 님을 {self.number} 팀에 추가했습니다.” 출력합니다.
    rm_member(): 이름을 인자로 받고 해당 이름이 member 요소로 있는 지 확인하고 있으면 member 요소에서 삭제하고 “000 님을 {self.number} 팀에서 삭제했습니다.” 출력합니다. 없으면 “000 님은 해당 팀에 없습니다.” 출력하고 메서드를 종료합니다.
    get_count(), get_order()는 각각 count와 order의 값을 반환합니다.
    set_order()는 숫자를 하나 인자로 받아와서 그 값을 order 맨 뒤에 추가합니다. 이때 이미 값이 있는 경우 앞의 값은 전부 지우고 맨 뒤에 값을 추가합니다.
    """
    count = 0
    order = []
    
    def __init__(self, number, name = None): # 초기화 될때 1번으로 실행되는게 __init__(self) 이 특별 메소드이다.
        self.number = number
        self.name = name
        self.__member = set()
        Team.count += 1
    def add_member(self, name):
        if name in self.__member:
            print(f'{name}님은 이미 팀에 있습니다.')
            return
        else:
            self.__member.add(name)
            print(f'{name}님을 {self.number}팀에 추가했습니다.')
            return
                  
    def rm_member(self, name):
                
        if name in self.__member:
            self.__member.discard(name)
            print(f'{name}님을 {self.number}팀에서 삭제했습니다.')
            return
        else:
            print(f'{name}님을 해당 팀에 없습니다.')
            return
                  
    def __len__(self):
        return len(self.__member)
                  
    def get_count(self):
        return Team.count
                  
    def get_order(self):
        return Team.order
    
    def set_order(self,num):
        if num not in Team.order:
            Team.order.remove(num)
        Team.order.append(num)

# %%
class TeamBuilder:
    has_team = False
    teams = []
    def __init__(self, members,team_count):
        self.team_count = team_count
        self.members = members
        has_team = True
    def create_teams(self):
        n = len(self.members)//self.team_count # 팀의 인원수
        for i in range(1,self.team_count+1):
            #if has_team == True:
               # pass
            mem_list = random.sample(self.members,n)
            t = Team(i) # 팀 순서대로 생성
            if len(self.members) == 1:
                mem_list.append(self.members[0])
                TeamBuilder.teams.append(self.members[0])
                t.add_member(self.members[0])
            for k in mem_list: # 인원 추가
                t.add_member(k)
                TeamBuilder.teams.append(k)
                self.members.remove(k)
        print(f'팀을 {self.team_count}개 생성했습니다.')
    def show_team_info(self):
        n2 = len(TeamBuilder.teams) // self.team_count # 3
        n3 = 0
        n22 = len(TeamBuilder.teams) // self.team_count
        for r in range(1,self.team_count+1):
            print(f'{r}팀은 {TeamBuilder.teams[n3:n2]}입니다') # 0.4/47
            n2 += n22
            n3 += n22

# %%
tb = TeamBuilder(['이기수'+str(_) for _ in range(11,33)],7)
tb.create_teams()
# Out:
# 이기수24님을 1팀에 추가했습니다.
# 이기수21님을 1팀에 추가했습니다.
# 이기수20님을 1팀에 추가했습니다.
# 이기수26님을 2팀에 추가했습니다.
# 이기수25님을 2팀에 추가했습니다.
# 이기수11님을 2팀에 추가했습니다.
# 이기수14님을 3팀에 추가했습니다.
# 이기수27님을 3팀에 추가했습니다.
# 이기수30님을 3팀에 추가했습니다.
# 이기수32님을 4팀에 추가했습니다.
# 이기수23님을 4팀에 추가했습니다.
# 이기수18님을 4팀에 추가했습니다.
# 이기수13님을 5팀에 추가했습니다.
# 이기수29님을 5팀에 추가했습니다.
# 이기수31님을 5팀에 추가했습니다.
# 이기수17님을 6팀에 추가했습니다.
# 이기수15님을 6팀에 추가했습니다.
# 이기수22님을 6팀에 추가했습니다.
# 이기수12님을 7팀에 추가했습니다.
# 이기수28님을 7팀에 추가했습니다.
# 이기수19님을 7팀에 추가했습니다.
# 팀을 7개 생성했습니다.

# %%
tb.show_team_info()
# Out:
# 1팀은 ['이기수24', '이기수21', '이기수20']입니다
# 2팀은 ['이기수26', '이기수25', '이기수11']입니다
# 3팀은 ['이기수14', '이기수27', '이기수30']입니다
# 4팀은 ['이기수32', '이기수23', '이기수18']입니다
# 5팀은 ['이기수13', '이기수29', '이기수31']입니다
# 6팀은 ['이기수17', '이기수15', '이기수22']입니다
# 7팀은 ['이기수12', '이기수28', '이기수19']입니다
